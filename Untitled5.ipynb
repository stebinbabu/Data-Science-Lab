# %%
import matplotlib.pyplot as plt
x = [10, 20, 30, 40]
y = [20, 25, 35, 55]
plt.plot(x, y)
plt.show()
# Out:
#   File "<ipython-input-5-460a8f3c9742>", line 6
#     plt.plot(x, y)
#     ^
# IndentationError: unexpected indent
