# %%
print("Vectorized sum example\n")
x = np.array([[1,2],[3,4]])
print("x:\n %s" %x)
print("sum: %s"%np.sum(x))  # Compute sum of all elements; prints "10"
print("sum axis = 0: %s" %np.sum(x, axis=0))  # Compute sum of each column; prints "[4 6]"
print(" sum axis = 1: %s" %np.sum(x, axis=1))
# Out:
# Vectorized sum example
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-dd9878fc3195> in <module>
#       1 print("Vectorized sum example\n")
# ----> 2 x = np.array([[1,2],[3,4]])
#       3 print("x:\n %s" %x)
#       4 print("sum: %s"%np.sum(x))  # Compute sum of all elements; prints "10"
#       5 print("sum axis = 0: %s" %np.sum(x, axis=0))  # Compute sum of each column; prints "[4 6]"
#
# NameError: name 'np' is not defined
